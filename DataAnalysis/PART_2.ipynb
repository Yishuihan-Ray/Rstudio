# %%
# %load_ext rpy2.ipython

# %% [markdown]
# **Problem 2 (10.2):**

# %%
# %%R
# dissimilarity = as.dist(matrix(c(0, 0.3, 0.4, 0.7, 0.3, 0, 0.5, 0.8, 0.4, 0.5,
#     0, 0.45, 0.7, 0.8, 0.45, 0), 4, 4))

# %% [markdown]
# **a) Complete linkage:**

# %%
# %%R
# plot(hclust(dissimilarity), axes = F, xlab = NA)
# axis(2, at = c(0.3, 0.45, 0.8))

# %% [markdown]
# **a) Complete linkage:**

# %%
# %%R
# plot(hclust(dissimilarity, method = "single"), axes = F, xlab = NA)
# axis(2, at = c(0.3, 0.4, 0.45))
